# %%
import requests, json
import pandas as pd

# %%
# https://data.cdc.gov/resource/vbim-akqf.json

# %%
url ='https://data.cdc.gov/resource/vbim-akqf.json'
res_jess = requests.get('https://data.cdc.gov/resource/vbim-akqf.json')
print(res_jess.status_code)
# Out:
# 200

# %%
print(res_jess.text)
# Out:
# [{"cdc_report_dt":"2020-11-10T00:00:00.000","pos_spec_dt":"2020-11-10T00:00:00.000","current_status":"Laboratory-confirmed case","sex":"Male","age_group":"10 - 19 Years","race_ethnicity_combined":"Black, Non-Hispanic","hosp_yn":"No","icu_yn":"Unknown","death_yn":"No","medcond_yn":"No"}
# ,{"cdc_report_dt":"2020-11-14T00:00:00.000","pos_spec_dt":"2020-11-10T00:00:00.000","onset_dt":"2020-11-10T00:00:00.000","current_status":"Laboratory-confirmed case","sex":"Male","age_group":"10 - 19 Years","race_ethnicity_combined":"Black, Non-Hispanic","hosp_yn":"No","icu_yn":"No","death_yn":"No","medcond_yn":"No"}
# ,{"cdc_report_dt":"2020-11-19T00:00:00.000","pos_spec_dt":"2020-11-10T00:00:00.000","onset_dt":"2020-11-09T00:00:00.000","current_status":"Laboratory-confirmed case","sex":"Male","age_group":"10 - 19 Years","race_ethnicity_combined":"Black, Non-Hispanic","hosp_yn":"No","icu_yn":"No","death_yn":"No","medcond_yn":"No"}
# ...

# %%
var_one = json.loads(res_jess.text)
var_one
# Out:
# [{'cdc_report_dt': '2020-11-10T00:00:00.000',
#   'pos_spec_dt': '2020-11-10T00:00:00.000',
#   'current_status': 'Laboratory-confirmed case',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No',
#   'medcond_yn': 'No'},
#  {'cdc_report_dt': '2020-11-14T00:00:00.000',
#   'pos_spec_dt': '2020-11-10T00:00:00.000',
#   'onset_dt': '2020-11-10T00:00:00.000',
#   'current_status': 'Laboratory-confirmed case',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
#   'race_ethnicity_combined': 'Black, Non-Hispanic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No',
#   'medcond_yn': 'No'},
#  {'cdc_report_dt': '2020-11-19T00:00:00.000',
#   'pos_spec_dt': '2020-11-10T00:00:00.000',
#   'onset_dt': '2020-11-09T00:00:00.000',
#   'current_status': 'Laboratory-confirmed case',
#   'sex': 'Male',
#   'age_group': '10 - 19 Years',
# ...
