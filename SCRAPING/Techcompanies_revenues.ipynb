# %%
# the Goal here is to take a look at Top Tech companies Revenues for a certain Period
# Using this website (https://fourweekmba.com/fang-companies/)

# %%
#importing the Necessary Libraries
import urllib.request
import bs4
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# https://fourweekmba.com/fang-companies/ Main URL of the Website that It going to be Scrapped!
url = 'https://fourweekmba.com/fang-companies/'
connection=urllib.request.urlopen(url) 
data=BeautifulSoup(connection)

# %%
# Another Way of Grabbing the Title of the Wb page

result = requests.get('https://fourweekmba.com/fang-companies/')

# %%
print(result)
# Out:
# <Response [200]>

# %%
print(type(result))
# Out:
# <class 'requests.models.Response'>

# %%
# We Have a giant string that we need to convert!
result.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" class="no-js">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width">\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://fourweekmba.com/xmlrpc.php">\n\t<!-- Manifest added by SuperPWA - Progressive Web Apps Plugin For WordPress -->\n<link rel="manifest" href="/superpwa-manifest.json">\n<meta name="theme-color" content="#D5E0EB">\n<!-- / SuperPWA.com -->\n\n\t<!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>FAANG Companies: Inside FAANG Business Models - FourWeekMBA</title>\n\t<meta name="description" content="FAANG is an acronym that comprises the hottest tech companies&#039; stocks in 2019. Those are Facebook, Amazon, Apple, Netflix and Alphabet&#039;s Google. The term was coined by Jim Cramer, former hedge fund manager and\xa0host of CNBC&#039;s Mad Money\xa0and founder of the publication TheStreet." />\
# ...

# %%
# result.table.text

# %%
# converting the String into a Python object
soup = bs4.BeautifulSoup(result.text, 'lxml')

# %%
# This is the output!
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://fourweekmba.com/xmlrpc.php" rel="pingback"/>
# <!-- Manifest added by SuperPWA - Progressive Web Apps Plugin For WordPress -->
# <link href="/superpwa-manifest.json" rel="manifest"/>
# <meta content="#D5E0EB" name="theme-color"/>
# <!-- / SuperPWA.com -->
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>FAANG Companies: Inside FAANG Business Models - FourWeekMBA</title>
# <meta content="FAANG is an acronym that comprises the hottest tech companies' stocks in 2019. Those are Facebook, Amazon, Apple, Netflix and Alphabet's Google. The term was coined by Jim Cramer, former hedge fund manager and host of CNBC's Mad Money and founder of the publication TheStreet." name="description"/>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://fourweekmba.com/xmlrpc.php" rel="pingback"/>
# <!-- Manifest added by SuperPWA - Progressive Web Apps Plugin For WordPress -->
# <link href="/superpwa-manifest.json" rel="manifest"/>
# <meta content="#D5E0EB" name="theme-color"/>
# <!-- / SuperPWA.com -->
# <!-- This site is optimized with the Yoast SEO plugin v15.4 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>FAANG Companies: Inside FAANG Business Models - FourWeekMBA</title>
# <meta content="FAANG is an acronym that comprises the hottest tech companies' stocks in 2019. Those are Facebook, Amazon, Apple, Netflix and Alphabet's Google. The term was coined by Jim Cramer, former hedge fund manager and host of CNBC's Mad Money and founder of the publication TheStreet." name="description"/>
# ...

# %%
# From the soup Object we can now Grab the element of interest by the Tags Names
# it should be returning each called elements in a form of a list
soup.select('title')
# Out:
# [<title>FAANG Companies: Inside FAANG Business Models - FourWeekMBA</title>]

# %%
soup.select('title')[0].getText()
# Out:
# 'FAANG Companies: Inside FAANG Business Models - FourWeekMBA'

# %%
# print(soup.body.contents)

# %%
print(soup.find_all('div'))
# Out:
# [<div class="headerblock alternative">
# <div class="content site-content">
# <a class="skip-link screen-reader-text" href="#content">Skip to content</a>
# <header class="site-header" id="masthead" role="banner">
# <div class="header-inner">
# <div class="site-logo">
# <a class="site-logo-link" href="https://fourweekmba.com/" itemprop="url" rel="home"></a> <div class="brand">
# <h1 class="site-title"><a href="https://fourweekmba.com/" rel="home">FourWeekMBA</a></h1>
# <h2 class="site-description">The Leading Source Of Original Research And Insights On Business Model Strategy And Digital Business Models</h2>
# </div>
# </div><!-- .site-logo -->
# <div id="secondary">
# <nav class="navigation-main" id="site-navigation" role="navigation">
# <a class="menu-toggle anarielgenericon"><span>Menu</span></a>
# ...

# %%
soup.select('.toc_container')
# Out:
# []

# %%
# soup.select('div')[0].getText()
# Out:
# '\n\nSkip to content\n\n\n\n \nFourWeekMBA\nThe Leading Source Of Original Research And Insights On Business Model Strategy And Digital Business Models\n\n\n\n\nMenu\nAbout\nBusiness Models\nBusiness Strategy\nMarketing Strategy\nBMI Course\nBizModels Book\nStore\n \n\n\n\n\n'

# %%
data.h1
# Out:
# <h1 class="site-title"><a href="https://fourweekmba.com/" rel="home">FourWeekMBA</a></h1>
