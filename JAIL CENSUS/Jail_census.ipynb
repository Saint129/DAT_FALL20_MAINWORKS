# %%
# Quick way of opening the file!
import csv
 
jail_file = open("Jail_Census_Data.csv", "r")

csv_reader = csv.reader(jail_file)

for row in csv_reader:
    print(row)

jail_file.close()
# Out:
# ['_id', 'date', 'gender', 'race', 'agebook', 'agecurr']
# ['1', '2018-01-01', 'M', 'B', '26', '28']
# ['2', '2018-01-01', 'M', 'W', '59', '60']
# ['3', '2018-01-01', 'M', 'B', '23', '24']
# ['4', '2018-01-01', 'M', 'W', '51', '52']
# ['5', '2018-01-01', 'M', 'B', '20', '21']
# ['6', '2018-01-01', 'M', 'B', '20', '21']
# ['7', '2018-01-01', 'M', 'B', '31', '32']
# ['8', '2018-01-01', 'M', 'W', '34', '36']
# ['9', '2018-01-01', 'M', 'W', '28', '29']
# ['10', '2018-01-01', 'M', 'B', '25', '26']
# ['11', '2018-01-01', 'M', 'B', '27', '28']
# ['12', '2018-01-01', 'M', 'B', '29', '30']
# ['13', '2018-01-01', 'M', 'W', '28', '29']
# ['14', '2018-01-01', 'M', 'W', '57', '58']
# ['15', '2018-01-01', 'M', 'B', '25', '26']
# ['16', '2018-01-01', 'M', 'B', '26', '27']
# ['17', '2018-01-01', 'M', 'B', '51', '52']
# ['18', '2018-01-01', 'M', 'B', '37', '38']
# ['19', '2018-01-01', 'M', 'B', '44', '45']
# ['20', '2018-01-01', 'M', 'B', '23', '23']
# ['21', '2018-01-01', 'M', 'B', '37', '37']
# ...
