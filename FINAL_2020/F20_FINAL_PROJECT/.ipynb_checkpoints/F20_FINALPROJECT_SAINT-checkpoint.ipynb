# %% [markdown]
# # COVID 19 SPIKE - ANALYSIS: CASE OF ALLEGHENY COUNTY

# %% [markdown]
# As We currently witness a surge in the number of covid-19 cases in pretty much all countries accross the globe,I believe that it will be important to see how the US is doing! The goal of this project focuses on impact of spike at both macro/micro levels in the US. Therefore through the differents datasets will try to answer the following:

# %% [markdown]
# 1.) What is the Current Status of the Surge: How many confirmed cases, new cases, an probable Cases are we having today ?
#
#
# 2.) Categorical Analysis:
#
#     2.1- Which Age Group is Mostly affected By the Surge?
#
#     2.2- What is the Sex and the Ethinicity of the Poeple affected by the Spkike of the Virus?
#
# 3.) Advanced Analysis
#
#        3.1- Covid Viral Opportunities
#
#        3.2- Covid-19 Hot Spots

# %%
import requests, json
import pandas as pd
import requests, json
from pandas import Series, DataFrame
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as plt
import seaborn as sns
# in order to have Plots appear in the iPython Notebook
# %matplotlib inline

# %%
# api_endpoint = 'https://data.cdc.gov/resource/vbim-akqf.json'
# resp_json = requests.get('https://data.cdc.gov/resource/vbim-akqf.json')
# print(resp_json.status_code)

# %%
# print(resp_json.text)

# %%
# states_datacovid = json.loads(resp_json.text)
# df_states_datacovid = DataFrame(states_datacovid)

# %%
# df_states_datacovid

# %%
# df_states_datacovid.shape

# %%
# df_states_datacovid.tail()

# %%
# api_endpoint = 'https://data.cdc.gov/resource/vbim-akqf.json'
# resp_json = requests.get('https://data.cdc.gov/resource/vbim-akqf.json')
# print(resp_json.status_code)
# print(resp_json.text)
# states_datacovid = json.loads(resp_json.text)
# df_states_datacovid = DataFrame(states_datacovid)

# %%
# df_states_datacovid

# %%
# Building Request URL for sending to CDC API
import requests
api_endpoint = 'https://data.cdc.gov/resource/'

def building_CDC_URL():
    rout_tojsonfile = 'vbim-akqf.json'
    url_four = api_endpoint + rout_tojsonfile
    return url_four

# %%
def make_APIreq(url_four):
    resp = requests.get(url_four)
    print(resp.status_code)
    if(int(resp.status_code) == 200):
        payload = json.loads(resp.text)
        return payload
    else:
        return{}

# %%
result = make_APIreq(building_CDC_URL()) 
print(result)
# Out:
# 200
# [{'cdc_report_dt': '2020-11-10T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'Unknown', 'death_yn': 'No', 'medcond_yn': 'No'}, {'cdc_report_dt': '2020-11-14T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'onset_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'No', 'death_yn': 'No', 'medcond_yn': 'No'}, {'cdc_report_dt': '2020-11-19T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'onset_dt': '2020-11-09T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'No', 'death_yn': 'No', 'medcond_yn': 'No'}, {'cdc_report_dt': '2020-11-14T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Missing', 'icu_yn': 'Missing', 'death_yn': 'No', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-13T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'onset_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'No', 'death_yn': 'No', 'medcond_yn': 'Yes'}, {'cdc_report_dt': '2020-11-17T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'onset_dt': '2020-11-08T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Missing', 'icu_yn': 'Missing', 'death_yn': 'Missing', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-14T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'Missing', 'death_yn': 'Missing', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-10T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Missing', 'icu_yn': 'Missing', 'death_yn': 'Missing', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-10T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Unknown', 'icu_yn': 'Unknown', 'death_yn': 'No', 'medcond_yn': 'Unknown'}, {'cdc_report_dt': '2020-11-17T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Missing', 'icu_yn': 'Missing', 'death_yn': 'Missing', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-10T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'Missing', 'icu_yn': 'Missing', 'death_yn': 'Missing', 'medcond_yn': 'Missing'}, {'cdc_report_dt': '2020-11-09T00:00:00.000', 'pos_spec_dt': '2020-11-10T00:00:00.000', 'onset_dt': '2020-11-09T00:00:00.000', 'current_status': 'Laboratory-confirmed case', 'sex': 'Male', 'age_group': '10 - 19 Years', 'race_ethnicity_combined': 'Black, Non-Hispanic', 'hosp_yn': 'No', 'icu_yn': 'No', 'death_yn': 'No', 'medcond_yn': 'No'}, {'cdc_report_dt': '2020-11-10T00:00:00.000', 'pos_spec_dt': ' ...

# %%
test_df = DataFrame(result)
